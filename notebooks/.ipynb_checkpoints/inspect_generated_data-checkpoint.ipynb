# %%
import os

# %%
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\timov\\Desktop\\Utrecht\\Utrecht\\MSBBSS\\Thesis'

# %%
df = pd.read_csv('Runs\LLM_search_based_Sep_Donners\generated_data\dataset_without_priors.csv')

# %%
df.head()
# Out:
#    original_dataset                                              title  \
# 0  Donners_2021.csv  Innovative Pharmacological Therapies for the H...
# 1  Donners_2021.csv  Generation of a Novel Bispecific Antibody (ACE...
# 2  Donners_2021.csv  Novel therapies and current clinical progress ...
# 3  Donners_2021.csv  Patient and Family Engagement during Treatment...
# 4  Donners_2021.csv  Emerging Therapeutic Strategies in the Treatme...
#
#                                             abstract  included  makita_priors
# 0  In recent years, advances in the pharmacologic...         0              0
# 1  Abstract Abstract 1126 Exogenous factor VIII (...         0              0
# 2  The evolution of hemophilia treatment and care...         0              0
# 3  Introduction: Treatment options to prevent ble...         0              0
# 4  Abstract The development of therapeutic strate...         0              0

# %%
sum(df["makita_priors"] == 1)
# Out:
# 0
