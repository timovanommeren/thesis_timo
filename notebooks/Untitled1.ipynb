# %%
from tempfile import TemporaryDirectory
import asreview as asr
import pathlib as Path

tmpdir = TemporaryDirectory()

# %%
project = asr.Project.load(r'C:\Users\timov\Desktop\Utrecht\Utrecht\MSBBSS\thesis_timo\simulations\Making_LLM_template\llm\output\simulation\Sep_2021_llm_prior\state_files\sim_Sep_2021.asreview', tmpdir.name)

# %%
project.config
# Out:
# {'version': '2.1.1',
#  'id': 'sim_Sep_2021',
#  'mode': 'simulate',
#  'name': 'Sep_2021',
#  'created_at_unix': 1760558189,
#  'reviews': [{'id': '091a86ea8fae4933b6150b84b8f7952a', 'status': 'finished'}],
#  'feature_matrices': [],
#  'tags': None,
#  'datasets': [{'id': 'Sep_2021.csv', 'name': 'Sep_2021.csv'}]}

# %%
tmpdir_path = Path(tmpdir.name)
for path in tmpdir_path.rglob("*"):
    print(path.relative_to(tmpdir_path))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tmpdir_path = Path(tmpdir.name)
#       2 for path in tmpdir_path.rglob("*"):
#       3     print(path.relative_to(tmpdir_path))
#
# TypeError: 'module' object is not callable

# %%
tmpdir.name
# Out:
# 'C:\\Users\\timov\\AppData\\Local\\Temp\\tmp0r5pd77z'
